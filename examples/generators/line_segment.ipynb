# %% [markdown]
# # line_segment

# %% [markdown]
# line_segment lists points of a line segment between the two points, X0 and X1.

# %% [markdown]
# ## Import packages

# %%
import numpy as np
import porespy as ps
import scipy
import matplotlib.pyplot as plt
ps.visualization.set_mpl_style()
np.random.seed(10)

# %% [markdown]
# ## Apply generator function:

# %% [markdown]
# ### 2D example

# %% [markdown]
# #### Create input points:

# %%
X0 = [1,200]
X1 = [100,1]

_2dx = [X0[0],X1[0]]
_2dy = [X0[1],X1[1]]

plt.figure(figsize=[7, 7])
plt.plot(_2dx, _2dy, 'o', color='black');

# %% [markdown]
# #### Generate line segment:

# %%
[_2dx,_2dy] = ps.generators.line_segment(X0, X1)

plt.figure(figsize=[7, 7])
plt.plot(_2dx, _2dy, 'o', color='black');

# %% [markdown]
# ### 3D example

# %% [markdown]
# #### Create input points:

# %%
X0 = [50,10,100]
X1 = [200,100,300]

_3dx = [X0[0],X1[0]]
_3dy = [X0[1],X1[1]]
_3dz = [X0[2],X1[2]]

fig = plt.figure(figsize=[10, 10])
ax = fig.add_subplot(111, projection='3d')
ax.scatter(_3dx, _3dy, _3dz, 'o', color='black')

# %% [markdown]
# #### Generate line segment:

# %%
_3dx,_3dy,_3dz = ps.generators.line_segment(X0, X1)

fig = plt.figure(figsize=[10, 10])
ax = fig.add_subplot(111, projection='3d')
ax.scatter(_3dx, _3dy,_3dz,'o', color='black')
