# %% [markdown]
# # perlin_noise

# %%
import numpy as np
import porespy as ps
import scipy
import matplotlib.pyplot as plt
ps.visualization.set_mpl_style()
np.random.seed(10)

# %% [markdown]
# perlin_noise creates an image of a perlin noise field.

# %%
shape = [1000,1000]
porosity = None
octaves = 3
frequency = [10,10]
persistence = 0.5

# %%
x = ps.generators.perlin_noise(shape, porosity, octaves, frequency, persistence)
plt.figure(figsize=[10, 10])
plt.axis(False)
fig = plt.imshow(x);
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:05<00:00,  1.92s/it]

# %% [markdown]
# While adding inputs to the function, the frequency must be a factor of shape, that when put to the power of octave is less than or equal to shape. If not, exceptions will be raised:

# %%
shape = [1000,1000]
porosity = None
octaves = 3
frequency = [5,5]
persistence = 0.5

# %%
x = ps.generators.perlin_noise(shape, porosity, octaves, frequency, persistence)
plt.figure(figsize=[10, 10])
plt.axis(False)
fig = plt.imshow(x);
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:04<00:00,  1.61s/it]
