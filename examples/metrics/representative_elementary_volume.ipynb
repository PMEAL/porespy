# %% [markdown]
# # representative_elementary_volume
# An example for the use of porespy.metrics.representative_elementary_volume

# %% [markdown]
# Calculates the porosity of the image as a function subdomain size.  This function extracts a specified number of subdomains of random size, then finds their porosity.

# %% [markdown]
# ### Import packages

# %%
import porespy as ps
import matplotlib.pyplot as plt

ps.visualization.set_mpl_style()

# %% [markdown]
# ### Create image:

# %%
skel = ps.generators.blobs(shape=[300, 300])
im = ps.filters.prune_branches(skel)

plt.figure(figsize=[10, 10])
plt.axis(False)
plt.imshow(im)

#default values:
npoints = 1000

# %% [markdown]
# ### Apply metric function:

# %% [markdown]
# Output is a tuple with elements volume and porosity.

# %% [markdown]
# ### default

# %%
profile = ps.metrics.representative_elementary_volume(im, npoints)
# Out:
# 100%|██████████| 981/981 [00:00<00:00, 27995.70it/s]

# %% [markdown]
# Plot results:

# %%
fig, ax = plt.subplots(1, 2, figsize=[15, 7]);
ax[0].plot(profile.volume, "b.")
ax[1].plot(profile.porosity, "b.")
ax[0].set_title("Volume")
ax[1].set_title("Porosity")
# Out:
# Text(0.5, 1.0, 'Porosity')

# %% [markdown]
# ### npoints

# %%
profile = ps.metrics.representative_elementary_volume(im, 100)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 20064.60it/s]

# %% [markdown]
# Plot results:

# %%
fig, ax = plt.subplots(1, 2, figsize=[15, 7]);
ax[0].plot(profile.volume, "b.")
ax[1].plot(profile.porosity, "b.")
ax[0].set_title("Volume")
ax[1].set_title("Porosity")
# Out:
# Text(0.5, 1.0, 'Porosity')
