# %% [markdown]
# # chord_counts
# An example for the use of porespy.metrics.chord_counts

# %% [markdown]
# Finds the length of each chord in the supplied image and returns a list of their individual sizes

# %% [markdown]
# ### Import packages

# %%
import porespy as ps
import matplotlib.pyplot as plt
ps.visualization.set_mpl_style()

# %% [markdown]
# ### Create image:

# %% [markdown]
# The image was created with the blobs generator function and then applying the prune_branches filter, and plotted.

# %%
im = ps.generators.blobs(shape=[300, 300])
im = ps.filters.apply_chords(im, spacing=1, axis=0, trim_edges=True, label=False)

plt.figure(figsize=[10, 10])
plt.axis(False)
plt.imshow(im)

# %% [markdown]
# ### Apply metric function:

# %% [markdown]
# Output is an array of the chord lenghts.

# %%
x = ps.metrics.chord_counts(im)

# %% [markdown]
# #
#
# Plot results:

# %%
plt.figure(figsize=[10, 10])
plt.title('Histogram of Chord Lenghts')
plt.hist(x)
plt.show()
