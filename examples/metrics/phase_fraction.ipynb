# %% [markdown]
# # phase_fraction
# An example for the use of porespy.metrics.phase_fraction

# %% [markdown]
# Calculates the number (or fraction) of each phase in an image.

# %% [markdown]
# ## Import packages

# %%
import porespy as ps
import matplotlib.pyplot as plt

ps.visualization.set_mpl_style()

# %% [markdown]
# ## Create image and variables:

# %%
im = ps.generators.perlin_noise(shape=[300, 300], porosity=None, octaves=3, frequency=1, persistence=0.5)
im = ps.filters.snow_partitioning(
    im, dt=None, r_max=4, sigma=0.4, return_all=False, mask=True, randomize=True
)
plt.imshow(im)

#default values:
normed = True
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 19.03it/s]
# ------------------------------------------------------------
# Beginning SNOW Algorithm
# Converting supplied image (im) to boolean
# Peforming Distance Transform
# Applying Gaussian blur with sigma = 0.4
# Initial number of peaks:  4
# Peaks after trimming saddle points:  4
# Peaks after trimming nearby peaks:  3

# %% [markdown]
# ## Apply metric function:

# %% [markdown]
# Output is an array of the amount of voxels with the specified label.

# %%
x = ps.metrics.phase_fraction(im, normed)
xx = ps.metrics.phase_fraction(im, False)

print('normed = True', x)
print('normed = False',xx)
# Out:
# normed = True [0.6375     0.00854444 0.0798     0.27415556]
# normed = False [57375   769  7182 24674]

# %% [markdown]
# #
#
# Plot results:

# %%
plt.figure(figsize=[10, 10])
plt.title("Phase Fractions")
plt.plot(x)
plt.show()
