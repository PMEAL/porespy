# %% [markdown]
# # mesh_surface_area
# An example for the use of porespy.metrics.mesh_surface_area

# %% [markdown]
# Calculates the surface area of a meshed region

# %% [markdown]
# ## Import packages

# %%
import porespy as ps
import skimage
import matplotlib.pyplot as plt

ps.visualization.set_mpl_style()

# %% [markdown]
# ## Create input image and variables:

# %%
#default values:
verts = None
faces = None
mesh = None

# %% [markdown]
# ## Apply metric function:

# %% [markdown]
# Output is the surface area of the mesh.

# %% [markdown]
# ### mesh

# %%
im = ps.generators.blobs(shape=[300, 300])
mesh1 = ps.tools.mesh_region(region=im, strel=None)
plt.figure(figsize=[5, 5])
plt.axis(False)
plt.imshow(im)

ps.metrics.mesh_surface_area(mesh1, verts, faces)
# Out:
# 90474.15625

# %% [markdown]
# ### verts and faces

# %%
#volume = [15,10,30]
skel = ps.generators.blobs(shape=[30, 30, 30])
im = ps.filters.prune_branches(skel)
verts, faces, normals, values = skimage.measure.marching_cubes(im)

ps.metrics.mesh_surface_area(mesh, verts, faces)
# Out:
# 16432.71875
