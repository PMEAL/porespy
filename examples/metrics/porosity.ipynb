# %% [markdown]
# # porosity
# An example for the use of porespy.metrics.porosity

# %% [markdown]
# Calculates the porosity of an image assuming 1's are void space and 0's are solid phase.

# %% [markdown]
# ### Import packages

# %%
import porespy as ps
import matplotlib.pyplot as plt

ps.visualization.set_mpl_style()

# %% [markdown]
# ### Create input image and variables:

# %%
skel = ps.generators.blobs(shape=[300, 300])
branch_points = None
iterations = 10
im = ps.filters.prune_branches(skel, branch_points, iterations)

plt.figure(figsize=[10, 10])
plt.axis(False)
plt.imshow(im)

# %% [markdown]
# ### Apply metric function:

# %% [markdown]
# Output is the porosity of the input.

# %%
ps.metrics.porosity(im)
# Out:
# 0.5011333333333333
