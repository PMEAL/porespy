# %% [markdown]
# # `make_contiguous`

# %% [markdown]
# ## Import packages

# %%
import numpy as np
import porespy as ps
import scipy.ndimage as spim
import matplotlib.pyplot as plt
import skimage
ps.visualization.set_mpl_style()

# %% [markdown]
# ## Generate image for testing

# %%
im = np.random.randint(-10,10, [10,10], int)
print(im)
# Out:
# [[  8  -7  -7  -9 -10  -9 -10  -6   3   3]
#  [ -7  -8   3   6   8 -10   0  -2  -8   9]
#  [-10   9   4  -4   2  -5  -5   8   6  -9]
#  [-10 -10   5   3  -1  -9   3   2   3  -4]
#  [  9  -1   8  -6  -4  -1   6  -6   3  -1]
#  [ -8   6  -6   0  -8   1   9   1   7 -10]
#  [ -5   8  -9   9   9   4 -10  -6  -2   1]
#  [  1  -7  -6  -1   3   1  -9   4   2   4]
#  [  6   2 -10   9 -10   2   9   5 -10  -4]
#  [  6  -1   0  -4   6  -9  -4   5   2  -3]]

# %%
fig, ax = plt.subplots(1, 1, figsize=[4, 4])
ax.imshow(im)
ax.axis(False)
ax.set_title(f"Minimum = {im.min()}");

# %% [markdown]
# ## Demonstrate function

# %%
im1 = ps.tools.make_contiguous(im=im, mode='keep_zeros')

# %%
fig, ax = plt.subplots(1, 1, figsize=[4, 4]);
ax.imshow(im1)
ax.axis(False)
ax.set_title(f"Minimum = {im1.min()}");
