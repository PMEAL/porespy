# %% [markdown]
# # `make_contiguous`

# %% [markdown]
# ## Import packages

# %%
import numpy as np
import porespy as ps
import scipy.ndimage as spim
import matplotlib.pyplot as plt
import skimage
ps.visualization.set_mpl_style()

# %% [markdown]
# ## Generate image for testing

# %%
im = np.random.randint(-10,10, [10,10], int)
print(im)
# Out:
# [[ -6 -10   6   9   5  -7   6   3   9  -8]
#  [  1  -6  -6  -5   3  -6   7   9   2 -10]
#  [ -1   6 -10   6   4  -1  -4   1  -4  -5]
#  [ -6   4   1   4   6   3   6  -1   6   5]
#  [ -8  -6  -2   6   2   2  -1  -7  -9  -4]
#  [ -2  -2   6   7  -2   8  -4  -7   4  -4]
#  [  1  -9 -10  -6   2   8  -1  -3   1  -7]
#  [ -7  -1  -8   8  -2  -7  -6  -5  -3   3]
#  [  3  -5  -3 -10  -4   4   5   6   5  -2]
#  [  4  -6   9   4   6   2   6   4   6   1]]

# %%
fig, ax = plt.subplots(1, 1, figsize=[4, 4])
ax.imshow(im)
ax.axis(False)
ax.set_title(f"Minimum = {im.min()}");

# %% [markdown]
# ## Demonstrate function

# %%
im1 = ps.tools.make_contiguous(im=im, mode='keep_zeros')

# %%
fig, ax = plt.subplots(1, 1, figsize=[4, 4]);
ax.imshow(im1)
ax.axis(False)
ax.set_title(f"Minimum = {im1.min()}");
