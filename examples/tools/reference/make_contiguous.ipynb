# %% [markdown]
# # `make_contiguous`

# %% [markdown]
# ## Import packages

# %%
import numpy as np
import porespy as ps
import scipy.ndimage as spim
import matplotlib.pyplot as plt
import skimage
ps.visualization.set_mpl_style()

# %% [markdown]
# ## Generate image for testing

# %%
im = np.random.randint(-10,10, [10,10], int)
print(im)
# Out:
# [[  3   1   9  -5  -6   7  -2  -7   2  -8]
#  [  7   8   1   5   8   9   3   3  -4  -9]
#  [  7   8   1   1   4  -4   6  -4  -4  -7]
#  [  6   1   5   0 -10  -5  -8   8   6  -3]
#  [ -7  -8   4   6   0  -1   4   8   1  -5]
#  [  5   7   8   2  -1  -2   2   5 -10  -6]
#  [ -1  -2  -6  -8   3  -4 -10   3   2  -4]
#  [  9  -6  -1  -5  -7   3  -1   7  -1  -3]
#  [ -9   2  -3  -1   3   2  -5  -3   4   0]
#  [ -4   0   2   3   7   3   5  -8  -5  -3]]

# %%
fig, ax = plt.subplots(1, 1, figsize=[4, 4])
ax.imshow(im)
ax.axis(False)
ax.set_title(f"Minimum = {im.min()}");

# %% [markdown]
# ## Demonstrate function

# %%
im1 = ps.tools.make_contiguous(im=im, mode='keep_zeros')

# %%
fig, ax = plt.subplots(1, 1, figsize=[4, 4]);
ax.imshow(im1)
ax.axis(False)
ax.set_title(f"Minimum = {im1.min()}");
