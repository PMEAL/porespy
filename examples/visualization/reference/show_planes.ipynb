# %% [markdown]
# # show_planes

# %% [markdown]
# ## Import packages

# %%
import porespy as ps
import matplotlib.pyplot as plt
ps.visualization.set_mpl_style()

# %% [markdown]
# ## Create image:

# %%
im = ps.generators.blobs([100, 100, 100])

# %% [markdown]
# ## Display image:

# %%
x = ps.visualization.show_planes(im=im)

fig, ax = plt.subplots(figsize=[7, 7]);
plt.axis(False);
plt.imshow(x);
plt.title('default');

# %% [markdown]
# ### spacing

# %%
x = ps.visualization.show_planes(im=im, spacing = 2)

fig, ax = plt.subplots(figsize=[7, 7]);
plt.axis(False);
plt.imshow(x);
plt.title('spacing = 2');
