# %% [markdown]
# # trim_nonpercolating_paths
# an example for the use of porespy.filters.trim_nonpercolating_paths

# %%
import numpy as np
import porespy as ps
import scipy.ndimage as spim
import matplotlib.pyplot as plt
import skimage

# %% [markdown]
# Removes non-percolating paths.

# %%
im = np.zeros([300, 300])
im = ps.generators.RSA(im, radius=5, volume_fraction=0.9)
plt.figure(figsize=[10, 10])
plt.axis(False)
plt.imshow(im)
inlet_axis=0
outlet_axis=0
inlets=None
outlets=None
# Out:
# --------------------------------------------------------------------------------
# RSA: Adding spheres of size 5
# Initial volume fraction: 0.0
# Dilating foreground features by sphere radius
# Regenerating free_sites after 447 iterations
# Regenerating free_sites after 580 iterations
# Regenerating free_sites after 607 iterations
# Number of spheres inserted: 607
# Final volume fraction: 0.46536666666666665

# %% [markdown]
# Apply filter:

# %%
x = ps.filters.trim_nonpercolating_paths(im, inlet_axis, outlet_axis, inlets, outlets)
plt.figure(figsize=[10, 10])
plt.axis(False)
plt.imshow(x)
