# %% [markdown]
# # find_dt_artifacts
# an example for the use of porespy.filters.find_dt_artifacts

# %% [markdown]
# Finds points on a distance transform that are closer to wall than solid.

# %% [markdown]
# ## Import packages

# %%
import numpy as np
import porespy as ps
import scipy.ndimage as spim
import matplotlib.pyplot as plt
import skimage

# %% [markdown]
# ## Create image and variables:

# %%
im = np.zeros([300, 300])
im = ps.generators.RSA(im, radius=15, volume_fraction=0.5)
axis=0
dt = spim.distance_transform_edt(im)
plt.figure(figsize=[10, 10])
plt.axis(False)
plt.imshow(dt)
# Out:
# --------------------------------------------------------------------------------
# RSA: Adding spheres of size 15
# Initial volume fraction: 0.0
# Dilating foreground features by sphere radius
# Regenerating free_sites after 52 iterations
# Number of spheres inserted: 65
# Final volume fraction: 0.5033888888888889

# %% [markdown]
# ## Apply filter function:
# With different parameters

# %%
x = ps.filters.find_dt_artifacts(dt)
plt.figure(figsize=[10, 10])
plt.axis(False)
plt.imshow(x)
