# %% [markdown]
# # region_size
# an example for the use of porespy.filters.region_size

# %% [markdown]
# Replace each voxel with size of the region it's in.

# %% [markdown]
# ## Import packages

# %%
import numpy as np
import porespy as ps
import scipy.ndimage as spim
import matplotlib.pyplot as plt
import skimage

# %% [markdown]
# ## Create image and variables:

# %%
im = np.zeros([300, 300])
im = ps.generators.RSA(im, radius=25, volume_fraction=0.3)
im = ps.generators.RSA(im, radius=3, volume_fraction=0.7)
plt.figure(figsize=[10, 10])
plt.axis(False)
plt.imshow(im)
# Out:
# --------------------------------------------------------------------------------
# RSA: Adding spheres of size 25
# Initial volume fraction: 0.0
# Dilating foreground features by sphere radius
# Number of spheres inserted: 14
# Final volume fraction: 0.30193333333333333
# --------------------------------------------------------------------------------
# RSA: Adding spheres of size 3
# Initial volume fraction: 0.30193333333333333
# Dilating foreground features by sphere radius
# Regenerating free_sites after 852 iterations
# Regenerating free_sites after 1074 iterations
# Regenerating free_sites after 1128 iterations
# Number of spheres inserted: 1129
# Final volume fraction: 0.6155444444444444

# %% [markdown]
# ## Apply filter function:
# With different parameters

# %%
x = ps.filters.region_size(im)
plt.figure(figsize=[10, 10])
plt.axis(False)
plt.imshow(x)
