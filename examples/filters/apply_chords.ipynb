# %% [markdown]
# # apply_chords
# an example for the use of porespy.filters.apply_chords

# %%
import numpy as np
import porespy as ps
import scipy.ndimage as spim
import matplotlib.pyplot as plt
import skimage

# %% [markdown]
# Adds chords in the void space separated by 1 voxel plus the input spacing.The direction of the chords is controlled by the input.

# %% [markdown]
# Generate input image and variables:

# %%
im = np.zeros([300, 300])
im = ps.generators.RSA(im, radius=25, volume_fraction=0.3)
im = ps.generators.RSA(im, radius=3, volume_fraction=0.7)
plt.figure(figsize=[10, 10])
plt.axis(False)
plt.imshow(im)
spacing=1
axis=0
trim_edges=True
label=False
# Out:
# --------------------------------------------------------------------------------
# RSA: Adding spheres of size 25
# Initial volume fraction: 0.0
# Dilating foreground features by sphere radius
# Number of spheres inserted: 14
# Final volume fraction: 0.30193333333333333
# --------------------------------------------------------------------------------
# RSA: Adding spheres of size 3
# Initial volume fraction: 0.30193333333333333
# Dilating foreground features by sphere radius
# Regenerating free_sites after 863 iterations
# Regenerating free_sites after 1118 iterations
# Regenerating free_sites after 1141 iterations
# Number of spheres inserted: 1141
# Final volume fraction: 0.6188777777777777

# %% [markdown]
# Apply filters:

# %%
x = ps.filters.apply_chords(im, spacing=1, axis=0, trim_edges=True, label=False)
plt.figure(figsize=[10, 10])
plt.axis(False)
plt.imshow(x)
