# %% [markdown]
# # distance_transform_lin

# %%
import porespy as ps
from IPython.display import Markdown as show
show(ps.tools.show_docstring(ps.filters.distance_transform_lin))
# Out:
# ---
#  ## Documentation for ``distance_transform_lin``
#  ---
# **<span style="color:purple">distance&#95;transform&#95;lin</span>_(im, axis=0, mode='both')_**
#
#
# Replaces each void voxel with the linear distance to the nearest solid
# voxel along the specified axis.
#
#
# #### Parameters
# * im : <b><i>ND-array</i></b>  The image of the porous material with ``True`` values indicating
# 	the void phase (or phase of interest).
# * axis : <b><i>int</i></b>  The direction along which the distance should be measured, the
# 	default is 0 (i.e. along the x-direction).
# * mode : <b><i>str</i></b>  Controls how the distance is measured. Options are:
# 	- 'forward': Distances are measured in the increasing direction
# 	  along the specified axis
# 	- 'reverse': Distances are measured in the reverse direction.
# 	  'backward' is also accepted.
# 	- 'both': Distances are calculated in both directions (by
# 	  recursively calling itself), then reporting the minimum value of
# 	  the two results.
#
# #### Returns
# * image : <b><i>ndarray</i></b>  A copy of ``im`` with each foreground voxel containing the
# 	distance to the nearest background along the specified axis.
# ---

# %% [markdown]
# ## Import packages

# %%
import numpy as np
import porespy as ps
import scipy.ndimage as spim
import matplotlib.pyplot as plt
import skimage

# %% [markdown]
# ## Create image and variables:

# %%
im = np.zeros([300, 300])
im = ps.generators.RSA(im, radius=15, volume_fraction=0.5)
plt.figure(figsize=[10, 10])
plt.axis(False)
plt.imshow(im)

#default values:
axis=0
mode = "both"

# %% [markdown]
# ## Apply filter function:
# With different parameters

# %% [markdown]
# ### axis

# %%
x = ps.filters.distance_transform_lin(im=im, axis=axis, mode=mode)
xx = ps.filters.distance_transform_lin(im=im, axis=1, mode=mode)
fig, ax = plt.subplots(1, 2, figsize=[20, 20]);
ax[0].imshow(x);
ax[0].axis(False)
ax[1].imshow(xx);
ax[1].axis(False)
ax[0].set_title('axis = 0')
ax[1].set_title('axis = 1')
# Out:
# Text(0.5, 1.0, 'axis = 1')

# %% [markdown]
# ### mode

# %%
xx = ps.filters.distance_transform_lin(im=im, axis=axis, mode="forward")
xxx = ps.filters.distance_transform_lin(im=im, axis=axis, mode="reverse")
fig, ax = plt.subplots(1, 3, figsize=[20, 20]);
ax[0].imshow(x);
ax[0].axis(False)
ax[1].imshow(xx);
ax[1].axis(False)
ax[2].imshow(xxx);
ax[2].axis(False)
ax[0].set_title('mode = both')
ax[1].set_title('mode = forward')
ax[2].set_title('mode = reverse')
# Out:
# Text(0.5, 1.0, 'mode = reverse')
