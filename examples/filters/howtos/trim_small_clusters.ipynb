# %% [markdown]
# # trim_small_clusters
# an example for the use of porespy.filters.trim_small_clusters

# %%
import numpy as np
import porespy as ps
import scipy.ndimage as spim
import matplotlib.pyplot as plt
import skimage

# %% [markdown]
# trim_small_clusters removes clusters from images if they are smaller than the size given as an input.

# %% [markdown]
# Generate input images:

# %%
im = np.zeros([300, 300])
im1 = ps.generators.RSA(im, radius=5, volume_fraction=0.5)
im2 = ps.generators.RSA(im, radius=4, volume_fraction=0.5)
im3 = ps.generators.RSA(im, radius=3, volume_fraction=0.5)
im4 = ps.generators.RSA(im, radius=2, volume_fraction=0.5)
im5 = ps.generators.RSA(im, radius=1, volume_fraction=0.5)


fig, ax = plt.subplots(2, 3, figsize=[15, 10]);
ax[0,0].imshow(im1);
ax[0,1].imshow(im2);
ax[0,2].imshow(im3);
ax[1,0].imshow(im4);
ax[1,1].imshow(im5);

ax[0,0].axis(False);
ax[0,1].axis(False);
ax[0,2].axis(False);
ax[1,0].axis(False);
ax[1,1].axis(False);
ax[1,2].axis(False);
# Out:
# --------------------------------------------------------------------------------
# RSA: Adding spheres of size 5
# Initial volume fraction: 0.0
# Dilating foreground features by sphere radius
# Regenerating free_sites after 466 iterations
# Regenerating free_sites after 588 iterations
# Regenerating free_sites after 601 iterations
# Number of spheres inserted: 601
# Final volume fraction: 0.46076666666666666
# --------------------------------------------------------------------------------
# RSA: Adding spheres of size 4
# Initial volume fraction: 0.0
# Dilating foreground features by sphere radius
# Regenerating free_sites after 763 iterations
# Regenerating free_sites after 924 iterations
# Regenerating free_sites after 948 iterations
# Number of spheres inserted: 948
# Final volume fraction: 0.474
# --------------------------------------------------------------------------------
# RSA: Adding spheres of size 3
# Initial volume fraction: 0.0
# Dilating foreground features by sphere radius
# Regenerating free_sites after 1291 iterations
# Regenerating free_sites after 1638 iterations
# Regenerating free_sites after 1671 iterations
# Number of spheres inserted: 1671
# Final volume fraction: 0.46416666666666667
# --------------------------------------------------------------------------------
# RSA: Adding spheres of size 2
# Initial volume fraction: 0.0
# Dilating foreground features by sphere radius
# Regenerating free_sites after 3085 iterations
# Regenerating free_sites after 3766 iterations
# Regenerating free_sites after 3882 iterations
# Number of spheres inserted: 3884
# Final volume fraction: 0.3884
# --------------------------------------------------------------------------------
# RSA: Adding spheres of size 1
# Initial volume fraction: 0.0
# Dilating foreground features by sphere radius
# Number of spheres inserted: 10000
# Final volume fraction: 0.1111111111111111

# %% [markdown]
# Apply filter:

# %%
size=10

x1 = ps.filters.trim_small_clusters(im1, size=10)
x2 = ps.filters.trim_small_clusters(im2, size=10)
x3 = ps.filters.trim_small_clusters(im3, size=10)
x4 = ps.filters.trim_small_clusters(im4, size=10)
x5 = ps.filters.trim_small_clusters(im5, size=10)

fig, ax = plt.subplots(2, 3, figsize=[15, 10]);
ax[0,0].imshow(x1);
ax[0,1].imshow(x2);
ax[0,2].imshow(x3);
ax[1,0].imshow(x4);
ax[1,1].imshow(x5);

ax[0,0].axis(False);
ax[0,1].axis(False);
ax[0,2].axis(False);
ax[1,0].axis(False);
ax[1,1].axis(False);
ax[1,2].axis(False);
