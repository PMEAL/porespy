# %% [markdown]
# # trim_disconnected_blobs

# %% [markdown]
# ## Import packages

# %%
import numpy as np
import porespy as ps
import scipy.ndimage as spim
import scipy
import matplotlib.pyplot as plt
import skimage
ps.visualization.set_mpl_style()

# %% [markdown]
# ## Create image and variables:

# %%
im = np.zeros([100, 100])
#im = ps.generators.RSA(im, radius=25, volume_fraction=0.3)
im = ps.generators.RSA(im, radius=3, volume_fraction=0.7)
inlets = np.zeros([100, 100])
inlets  = ps.generators.RSA(inlets, radius=3, volume_fraction=0.01)

plt.figure(figsize=[7, 7])
plt.imshow(im);
plt.axis(False)

#default values:
strel = None

# %% [markdown]
# ## Apply filter function:
# With different parameters

# %% [markdown]
# ### inlets

# %%
x = ps.filters.trim_disconnected_blobs(im=im, inlets=inlets, strel=strel)

in2  = ps.generators.blobs([100,100], 0.2)
xx = ps.filters.trim_disconnected_blobs(im=im, inlets=in2, strel=strel)

fig, ax = plt.subplots(2, 2, figsize=[15, 15]);
ax[0,0].imshow(inlets);
ax[0,1].imshow(in2);
ax[0,0].axis(False)
ax[0,1].axis(False)
ax[0,0].set_title('inlets = RSA')
ax[0,1].set_title('inlets = blobs')

ax[1,0].imshow(x);
ax[1,1].imshow(xx);
ax[1,0].axis(False)
ax[1,1].axis(False)
ax[1,0].set_title('inlets = RSA - result')
ax[1,1].set_title('inlets = blobs - result')
# Out:
# Text(0.5, 1.0, 'inlets = blobs - result')

# %% [markdown]
# ### strel

# %%
xx = ps.filters.trim_disconnected_blobs(im=im, inlets=in2, strel=[100,100])
fig, ax = plt.subplots(1, 2, figsize=[15, 15]);

ax[0].imshow(x);
ax[1].imshow(xx);
ax[0].axis(False)
ax[1].axis(False)
ax[0].set_title('strel = None')
ax[1].set_title('strel = [100,100]')
# Out:
# Text(0.5, 1.0, 'strel = [100,100]')
