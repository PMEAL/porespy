# %% [markdown]
# # trim_nonpercolating_paths

# %% [markdown]
# ## Import packages

# %%
import numpy as np
import porespy as ps
import scipy.ndimage as spim
import matplotlib.pyplot as plt
import skimage
ps.visualization.set_mpl_style()

# %% [markdown]
# ## Create image and variables:

# %%
im = ps.generators.blobs(shape=[500, 500])
plt.figure(figsize=[10, 10])
plt.axis(False)
plt.imshow(im)

#default values:
inlet_axis=0
outlet_axis=0
inlets=None
outlets=None

# %% [markdown]
# ## Apply filter function:
# With different parameters

# %% [markdown]
# ### inlet_axis

# %%
x = ps.filters.trim_nonpercolating_paths(im=im, inlet_axis=inlet_axis, outlet_axis=outlet_axis, inlets=inlets, outlets= outlets)
xx = ps.filters.trim_nonpercolating_paths(im=im, inlet_axis=1, outlet_axis=outlet_axis, inlets=inlets, outlets=outlets)

fig, ax = plt.subplots(1, 2, figsize=[15, 15]);
ax[0].imshow(x);
ax[1].imshow(xx);
ax[0].axis(False)
ax[1].axis(False)
ax[0].set_title('inlet_axis = 0')
ax[1].set_title('inlet_axis = 1')
# Out:
# Text(0.5, 1.0, 'inlet_axis = 1')

# %% [markdown]
# ### outlet_axis

# %%
xx = ps.filters.trim_nonpercolating_paths(im=im, inlet_axis=inlet_axis, outlet_axis=1, inlets=inlets, outlets= outlets)

fig, ax = plt.subplots(1, 2, figsize=[15, 15]);
ax[0].imshow(x);
ax[1].imshow(xx);
ax[0].axis(False)
ax[1].axis(False)
ax[0].set_title('outlet_axis = 0')
ax[1].set_title('outlet_axis = 1')
# Out:
# Text(0.5, 1.0, 'outlet_axis = 1')

# %% [markdown]
# ### inlet

# %%
in2 = ps.generators.blobs([100,100])
xx = ps.filters.trim_nonpercolating_paths(im=im, inlet_axis=inlet_axis, outlet_axis=outlet_axis, inlets=in2, outlets= outlets)

fig, ax = plt.subplots(1, 2, figsize=[15, 15]);
ax[0].imshow(x);
ax[1].imshow(xx);
ax[0].axis(False)
ax[1].axis(False)
ax[0].set_title('inlets = None')
ax[1].set_title('inlets = Generated Blobs')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-c98314431f39> in <module>
#       1 in2 = ps.generators.blobs([100,100])
# ----> 2 xx = ps.filters.trim_nonpercolating_paths(im=im, inlet_axis=inlet_axis, outlet_axis=outlet_axis, inlets=in2, outlets= outlets)
#       3
#       4 fig, ax = plt.subplots(1, 2, figsize=[15, 15]);
#       5 ax[0].imshow(x);
#
# ~/Code/porespy/porespy/filters/__funcs__.py in trim_nonpercolating_paths(im, inlet_axis, outlet_axis, inlets, outlets)
#     838             elif outlet_axis == 1:
#     839                 outlets[:, -1] = True
# --> 840     IN = np.unique(labels * inlets)
#     841     OUT = np.unique(labels * outlets)
#     842     hits = np.array(list(set(IN).intersection(set(OUT))))
#
# ValueError: operands could not be broadcast together with shapes (500,500) (100,100)

# %% [markdown]
# ### outlets

# %%
out2 = ps.generators.blobs([100,100])
xx = ps.filters.trim_nonpercolating_paths(im=im, inlet_axis=inlet_axis, outlet_axis=outlet_axis, inlets=inlets, outlets=out2)

fig, ax = plt.subplots(1, 2, figsize=[15, 15]);
ax[0].imshow(x);
ax[1].imshow(xx);
ax[0].axis(False)
ax[1].axis(False)
ax[0].set_title('outlets = None')
ax[1].set_title('outlets = Generated Blobs')
