# %% [markdown]
# # trim_nonpercolating_paths

# %%
import porespy as ps
from IPython.display import Markdown as show
show(ps.tools.show_docstring(ps.filters.trim_nonpercolating_paths))
# Out:
# ---
#  ## Documentation for ``trim_nonpercolating_paths``
#  ---
# **<span style="color:purple">trim&#95;nonpercolating&#95;paths</span>_(im, inlet_axis=0, outlet_axis=0, inlets=None, outlets=None)_**
#
#
# Removes all nonpercolating paths between specified edges
#
#
# This function is essential when performing transport simulations on an
# image, since image regions that do not span between the desired inlet
# and outlet do not contribute to the transport.
#
# #### Parameters
# * im : <b><i>ndarray</i></b>  The image of the porous material with ```True`` values indicating
# 	the phase of interest
# * inlet_axis : <b><i>int</i></b>  Inlet axis of boundary condition. For three dimensional image the
# 	number ranges from 0 to 2. For two dimensional image the range is
# 	between 0 to 1. If ``inlets`` is given then this argument is
# 	ignored.
# * outlet_axis : <b><i>int</i></b>  Outlet axis of boundary condition. For three dimensional image the
# ...

# %% [markdown]
# ## Import packages

# %%
import numpy as np
import porespy as ps
import scipy.ndimage as spim
import matplotlib.pyplot as plt
import skimage
ps.visualization.set_mpl_style()

# %% [markdown]
# ## Create image and variables:

# %%
im = ps.generators.blobs(shape=[100, 100])
plt.figure(figsize=[10, 10])
plt.axis(False)
plt.imshow(im)

#default values:
inlet_axis=0
outlet_axis=0
inlets=None
outlets=None

# %% [markdown]
# ## Apply filter function:
# With different parameters

# %% [markdown]
# ### inlet_axis

# %%
x = ps.filters.trim_nonpercolating_paths(im=im, inlet_axis=inlet_axis, outlet_axis=outlet_axis, inlets=inlets, outlets= outlets)
xx = ps.filters.trim_nonpercolating_paths(im=im, inlet_axis=1, outlet_axis=outlet_axis, inlets=inlets, outlets=outlets)

fig, ax = plt.subplots(1, 2, figsize=[15, 15]);
ax[0].imshow(x);
ax[1].imshow(xx);
ax[0].axis(False)
ax[1].axis(False)
ax[0].set_title('inlet_axis = 0')
ax[1].set_title('inlet_axis = 1')
# Out:
# Text(0.5, 1.0, 'inlet_axis = 1')

# %% [markdown]
# ### outlet_axis

# %%
xx = ps.filters.trim_nonpercolating_paths(im=im, inlet_axis=inlet_axis, outlet_axis=1, inlets=inlets, outlets= outlets)

fig, ax = plt.subplots(1, 2, figsize=[15, 15]);
ax[0].imshow(x);
ax[1].imshow(xx);
ax[0].axis(False)
ax[1].axis(False)
ax[0].set_title('outlet_axis = 0')
ax[1].set_title('outlet_axis = 1')
# Out:
# Text(0.5, 1.0, 'outlet_axis = 1')

# %% [markdown]
# ### inlet

# %%
in2 = ps.generators.blobs([100,100])
xx = ps.filters.trim_nonpercolating_paths(im=im, inlet_axis=inlet_axis, outlet_axis=outlet_axis, inlets=in2, outlets= outlets)

fig, ax = plt.subplots(1, 2, figsize=[15, 15]);
ax[0].imshow(x);
ax[1].imshow(xx);
ax[0].axis(False)
ax[1].axis(False)
ax[0].set_title('inlets = None')
ax[1].set_title('inlets = Generated Blobs')
# Out:
# Text(0.5, 1.0, 'inlets = Generated Blobs')

# %% [markdown]
# ### outlets

# %%
out2 = ps.generators.blobs([100,100])
xx = ps.filters.trim_nonpercolating_paths(im=im, inlet_axis=inlet_axis, outlet_axis=outlet_axis, inlets=inlets, outlets=out2)

fig, ax = plt.subplots(1, 2, figsize=[15, 15]);
ax[0].imshow(x);
ax[1].imshow(xx);
ax[0].axis(False)
ax[1].axis(False)
ax[0].set_title('outlets = None')
ax[1].set_title('outlets = Generated Blobs')
# Out:
# Text(0.5, 1.0, 'outlets = Generated Blobs')
