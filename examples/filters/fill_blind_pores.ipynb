# %% [markdown]
# # fill_blind_pores
# an example for the use of porespy.filters.fill_blind_pores

# %%
import numpy as np
import porespy as ps
import scipy.ndimage as spim
import matplotlib.pyplot as plt
import skimage

# %% [markdown]
# Fills pores that aren't connected to the edges of an image.

# %%
im = np.zeros([300, 300])
im = ps.generators.RSA(im, radius=5, volume_fraction=0.9)
plt.figure(figsize=[10, 10])
plt.axis(False)
plt.imshow(im)
conn = None
# Out:
# --------------------------------------------------------------------------------
# RSA: Adding spheres of size 5
# Initial volume fraction: 0.0
# Dilating foreground features by sphere radius
# Regenerating free_sites after 426 iterations
# Regenerating free_sites after 571 iterations
# Regenerating free_sites after 602 iterations
# Number of spheres inserted: 603
# Final volume fraction: 0.4623

# %% [markdown]
# Apply filters:

# %%
x = ps.filters.fill_blind_pores(im, conn=None)
plt.figure(figsize=[10, 10])
plt.axis(False)
plt.imshow(x)
