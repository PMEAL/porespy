# %% [markdown]
# # reduce_peaks
# an example for the use of porespy.filters.reduce_peaks

# %%
import numpy as np
import porespy as ps
import scipy.ndimage as spim
import matplotlib.pyplot as plt
import skimage

# %% [markdown]
# Wide peaks are reduced to one voxel at the center of the location of the original peak's voxels.

# %% [markdown]
# Create input peaks:

# %%
im = np.zeros([300, 300])
im = ps.generators.RSA(im, radius=15, volume_fraction=0.5)
dt = ps.filters.distance_transform_lin(im, axis = 1, mode = "both")
r_max = 4
footprint = None
peaks = ps.filters.find_peaks(dt, r_max=4, footprint=None)
plt.figure(figsize=[10, 10])
plt.axis(False)
plt.imshow(peaks)
# Out:
# --------------------------------------------------------------------------------
# RSA: Adding spheres of size 15
# Initial volume fraction: 0.0
# Dilating foreground features by sphere radius
# Regenerating free_sites after 55 iterations
# Regenerating free_sites after 59 iterations
# Regenerating free_sites after 63 iterations
# Number of spheres inserted: 63
# Final volume fraction: 0.4879

# %% [markdown]
# Apply filter:

# %%
x = ps.filters.reduce_peaks(peaks)
plt.figure(figsize=[10, 10])
plt.axis(False)
plt.imshow(x)
