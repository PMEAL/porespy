# %%
import numpy as np
import porespy as ps
import scipy.ndimage as spim
import matplotlib.pyplot as plt
import skimage

# %% [markdown]
# Removes dangling ends or tails of a skeleton.

# %%
im = np.zeros([300, 300])
im = ps.generators.RSA(im, radius=25, volume_fraction=0.3)
skel = ps.generators.RSA(im, radius=3, volume_fraction=0.7)
plt.imshow(skel)
branch_points = None
iterations = 1
# Out:
# --------------------------------------------------------------------------------
# RSA: Adding spheres of size 25
# Initial volume fraction: 0.0
# Dilating foreground features by sphere radius
# Number of spheres inserted: 14
# Final volume fraction: 0.30193333333333333
# --------------------------------------------------------------------------------
# RSA: Adding spheres of size 3
# Initial volume fraction: 0.30193333333333333
# Dilating foreground features by sphere radius
# Regenerating free_sites after 910 iterations
# Regenerating free_sites after 1109 iterations
# Regenerating free_sites after 1135 iterations
# Number of spheres inserted: 1135
# Final volume fraction: 0.6172111111111112

# %% [markdown]
# Apply filters:

# %%
x = ps.filters.prune_branches(skel, branch_points=None, iterations=1)
plt.imshow(x)
