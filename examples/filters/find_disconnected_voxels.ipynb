# %% [markdown]
# # find_disconnected_voxels
# an example for the use of porespy.filters.find_disconnected_voxels

# %%
import numpy as np
import porespy as ps
import scipy.ndimage as spim
import matplotlib.pyplot as plt
import skimage

# %% [markdown]
# Finds all of the voxels for pores or solids that are not connected to the edges of the image.

# %% [markdown]
# Generate input image:

# %%
im = np.zeros([300, 300])
im = ps.generators.RSA(im, radius=15, volume_fraction=0.9)
conn = None
plt.figure(figsize=[10, 10])
plt.axis(False)
plt.imshow(im)
# Out:
# --------------------------------------------------------------------------------
# RSA: Adding spheres of size 15
# Initial volume fraction: 0.0
# Dilating foreground features by sphere radius
# Regenerating free_sites after 52 iterations
# Regenerating free_sites after 64 iterations
# Number of spheres inserted: 66
# Final volume fraction: 0.5111333333333333

# %% [markdown]
# Apply filter:

# %%
x = ps.filters.find_disconnected_voxels(im, conn=None)
plt.figure(figsize=[10, 10])
plt.axis(False)
plt.imshow(x)
