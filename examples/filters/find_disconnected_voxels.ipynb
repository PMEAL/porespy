# %%
import numpy as np
import porespy as ps
import scipy.ndimage as spim
import matplotlib.pyplot as plt
import skimage

# %% [markdown]
# Finds all of the voxels for pores or solids that are not connected to the edges of the image.

# %% [markdown]
# generate input image:

# %%
im = np.zeros([300, 300])
im = ps.generators.RSA(im, radius=15, volume_fraction=0.9)
conn = None
# Out:
# --------------------------------------------------------------------------------
# RSA: Adding spheres of size 15
# Initial volume fraction: 0.0
# Dilating foreground features by sphere radius
# Regenerating free_sites after 50 iterations
# Regenerating free_sites after 62 iterations
# Regenerating free_sites after 65 iterations
# Number of spheres inserted: 65
# Final volume fraction: 0.5033888888888889

# %% [markdown]
# apply filter:

# %%
x = ps.filters.find_disconnected_voxels(im, conn=None)
plt.imshow(x)
